# %%
pip install ultralytics
# Out:
# ...
#    ---------------------------------------- 0.0/977.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/977.3 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/977.3 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/977.3 kB ? eta -:--:--
#    -------------------- ----------------- 524.3/977.3 kB 728.2 kB/s eta 0:00:01
#    -------------------- ----------------- 524.3/977.3 kB 728.2 kB/s eta 0:00:01
#    ------------------------------ ------- 786.4/977.3 kB 599.2 kB/s eta 0:00:01
#    ------------------------------ ------- 786.4/977.3 kB 599.2 kB/s eta 0:00:01
#    ------------------------------ ------- 786.4/977.3 kB 599.2 kB/s eta 0:00:01
#    -------------------------------------- 977.3/977.3 kB 514.1 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

# Charger le modèle
model = YOLO("yolov8n.pt")

# Entraîner le modèle avec affichage détaillé
model.train(data="C:/Users/user/Downloads/My First Project.v3i.yolov8/data.yaml", epochs=100, imgsz=640, verbose=True)
# Out:
# Ultralytics 8.3.101  Python-3.12.3 torch-2.6.0+cpu CPU (11th Gen Intel Core(TM) i5-11320H 3.20GHz)
# ...

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Charger ton modèle entraîné
model = YOLO("runs/detect/train6/weights/best.pt")

# Charger une image
image_path = r"C:\Users\emnad\Downloads\datasetsplit1\train\Bulletin_de_soin\1491--8753060--20230720_page_0.jpg"
results = model(image_path, conf=0.05)  # Réduire la confiance pour voir les faibles détections

# Afficher l'image avec les boxes
res_plotted = results[0].plot()
plt.imshow(cv2.cvtColor(res_plotted, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
# Out:
# image 1/1 C:\Users\emnad\Downloads\datasetsplit1\train\Bulletin_de_soin\1491--8753060--20230720_page_0.jpg: 448x640 7 manuscrits, 120.3ms
# Speed: 4.8ms preprocess, 120.3ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)

# %%
import os
image_path = "C:/Users/emnad/Downloads/datasetsplit1/train/Bulletin_de_soin/1491--8753060--20230720_page_0.jpg"

# Vérifier si l'image existe
if os.path.exists(image_path):
    print("✅ L'image existe bien.")
else:
    print("❌ L'image n'existe pas, vérifie le chemin !")
# Out:
# ✅ L'image existe bien.

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convertir BGR → RGB

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
import numpy as np

# Charger le modèle YOLOv8
model = YOLO("runs/detect/train6/weights/best.pt")

# Charger l'image
image_path = r"C:\Users\emnad\Downloads\datasetsplit1\test\Bulletin_de_soin\4199--8458991--20230830-4265_page_0.jpg"
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Conversion pour Matplotlib

# Détection avec un seuil de confiance bas
results = model(image_path, conf=0.05)

# Paramètres personnalisés pour les boîtes
box_alpha = 0.2  # Transparence du remplissage
line_width = 1    # Épaisseur des contours
font_scale = 0.6  # Taille du texte
text_color = (255, 0, 0)  # Couleur du texte (bleu)
box_color = (0, 255, 0)   # Couleur des boîtes (vert)

# Créer une copie pour l'annotation
annotated_image = image.copy()

for result in results:
    for box in result.boxes:
        # Coordonnées de la boîte
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        
        # Dessiner le rectangle avec transparence
        overlay = annotated_image.copy()
        cv2.rectangle(overlay, (x1, y1), (x2, y2), box_color, -1)  # Remplissage
        annotated_image = cv2.addWeighted(overlay, box_alpha, annotated_image, 1 - box_alpha, 0)
        
        # Contour de la boîte
        cv2.rectangle(annotated_image, (x1, y1), (x2, y2), box_color, line_width)
        
        # Texte (classe + confiance)
        label = f"{result.names[int(box.cls)]} {box.conf[0]:.2f}"
        cv2.putText(annotated_image, label, (x1, y1 - 5),
                   cv2.FONT_HERSHEY_SIMPLEX, font_scale, text_color, 1)

# Affichage
plt.figure(figsize=(12, 10))
plt.imshow(annotated_image)
plt.axis("off")

# Enregistrer le résultat si besoin
output_path = "detection_result.jpg"
cv2.imwrite(output_path, cv2.cvtColor(annotated_image, cv2.COLOR_RGB2BGR))
print(f"Résultat sauvegardé sous : {output_path}")

plt.show()
# Out:
# image 1/1 C:\Users\emnad\Downloads\datasetsplit1\test\Bulletin_de_soin\4199--8458991--20230830-4265_page_0.jpg: 448x640 15 manuscrits, 116.3ms
# Speed: 7.0ms preprocess, 116.3ms inference, 9.9ms postprocess per image at shape (1, 3, 448, 640)
# Résultat sauvegardé sous : detection_result.jpg

# %%
cv2.imwrite("detection_result.jpg", res_plotted)
print("✅ Image enregistrée sous 'detection_result.jpg' ✅")
# Out:
# ✅ Image enregistrée sous 'detection_result.jpg' ✅

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
import numpy as np
import os

# Charger le modèle YOLOv8
model = YOLO("runs/detect/train6/weights/best.pt")

# Charger l'image
image_path = r"C:\Users\emnad\Downloads\datasetsplit1\test\Bulletin_de_soin\4199--8458991--20230830-4265_page_0.jpg"
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Conversion pour Matplotlib

# Détection avec un seuil de confiance bas
results = model(image_path, conf=0.05)

# Paramètres personnalisés pour les boîtes
box_alpha = 0.2  # Transparence du remplissage
line_width = 1    # Épaisseur des contours
font_scale = 0.6  # Taille du texte
text_color = (255, 0, 0)  # Couleur du texte (bleu)
box_color = (0, 255, 0)   # Couleur des boîtes (vert)

# Créer une copie pour l'annotation
annotated_image = image.copy()

# Dossier pour sauvegarder les crops
output_dir = "crops"
os.makedirs(output_dir, exist_ok=True)

# Liste pour stocker les informations des crops
cropped_zones = []

for result in results:
    for idx, box in enumerate(result.boxes):
        # Coordonnées de la boîte
        x1, y1, x2, y2 = map(int, box.xyxy[0])

        # Ajouter une marge pour éviter de couper le texte
        margin = 10
        x1, y1, x2, y2 = max(0, x1 - margin), max(0, y1 - margin), x2 + margin, y2 + margin

        # Cropper la zone
        cropped_image = image[y1:y2, x1:x2]

        # Sauvegarder l'image croppée
        crop_filename = f"crop_{idx:03d}.png"
        crop_path = os.path.join(output_dir, crop_filename)
        cv2.imwrite(crop_path, cv2.cvtColor(cropped_image, cv2.COLOR_RGB2BGR))
        print(f"Zone croppée sauvegardée : {crop_path}")

        # Stocker les informations de la zone
        cropped_zones.append({
            "crop_path": crop_path,
            "label": result.names[int(box.cls)],
            "confidence": float(box.conf[0]),
            "coordinates": (x1, y1, x2, y2)
        })

        # Dessiner le rectangle avec transparence
        overlay = annotated_image.copy()
        cv2.rectangle(overlay, (x1, y1), (x2, y2), box_color, -1)  # Remplissage
        annotated_image = cv2.addWeighted(overlay, box_alpha, annotated_image, 1 - box_alpha, 0)

        # Contour de la boîte
        cv2.rectangle(annotated_image, (x1, y1), (x2, y2), box_color, line_width)

        # Texte (classe + confiance)
        label = f"{result.names[int(box.cls)]} {box.conf[0]:.2f}"
        cv2.putText(annotated_image, label, (x1, y1 - 5),
                    cv2.FONT_HERSHEY_SIMPLEX, font_scale, text_color, 1)

# Affichage
plt.figure(figsize=(12, 10))
plt.imshow(annotated_image)
plt.axis("off")

# Enregistrer le résultat si besoin
output_path = "detection_result.jpg"
cv2.imwrite(output_path, cv2.cvtColor(annotated_image, cv2.COLOR_RGB2BGR))
print(f"Résultat sauvegardé sous : {output_path}")

plt.show()

# Afficher les informations des zones croppées
for zone in cropped_zones:
    print(f"Zone: {zone['label']}, Confiance: {zone['confidence']:.2f}, Chemin: {zone['crop_path']}, Coordonnées: {zone['coordinates']}")
# Out:
# image 1/1 C:\Users\emnad\Downloads\datasetsplit1\test\Bulletin_de_soin\4199--8458991--20230830-4265_page_0.jpg: 448x640 15 manuscrits, 37.2ms
# Speed: 2.5ms preprocess, 37.2ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
# Zone croppée sauvegardée : crops\crop_000.png
# Zone croppée sauvegardée : crops\crop_001.png
# Zone croppée sauvegardée : crops\crop_002.png
# Zone croppée sauvegardée : crops\crop_003.png
# Zone croppée sauvegardée : crops\crop_004.png
# Zone croppée sauvegardée : crops\crop_005.png
# Zone croppée sauvegardée : crops\crop_006.png
# Zone croppée sauvegardée : crops\crop_007.png
# Zone croppée sauvegardée : crops\crop_008.png
# Zone croppée sauvegardée : crops\crop_009.png
# Zone croppée sauvegardée : crops\crop_010.png
# Zone croppée sauvegardée : crops\crop_011.png
# Zone croppée sauvegardée : crops\crop_012.png
# Zone croppée sauvegardée : crops\crop_013.png
# Zone croppée sauvegardée : crops\crop_014.png
# ...
