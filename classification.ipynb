# %%
pip install symspellpy
# Out:
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.6 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.6 MB 1.1 MB/s eta 0:00:02
#    ------------ --------------------------- 0.8/2.6 MB 1.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.0/2.6 MB 1.2 MB/s eta 0:00:02
#    -------------------- ------------------- 1.3/2.6 MB 1.2 MB/s eta 0:00:02
#    ------------------------ --------------- 1.6/2.6 MB 1.2 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.6 MB 1.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.8/2.6 MB 1.1 MB/s eta 0:00:01
#    -------------------------------- ------- 2.1/2.6 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 2.4/2.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 1.1 MB/s eta 0:00:00
# ...

# %%
pip install easyocr
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import pytesseract
from PIL import Image

# Chemin vers l'image
image = "C:/Users/emnad/Downloads/dataclass/bulletin_de_soin/bs1.jpg"

pytesseract.image_to_string(image, lang='fra+ara')  # Pour le français
# Out:
# 'L | Contractant\net cachet\n\nتوصيات هامة\n\nيجب على المؤمن له أن يوجه هذه البطاقة إلى تأمينات ستار في غضون ثلاثون يوماعلى أقصى تقدير من تاريخ الوصفة الطبية\n\nأو العلاج الطبي تفاديا لكل حرمان من التعويض. \u200eë\u200f ;\n\nيجب مصاحبة هذه البطاقة بالوثائق التالية :\n\nالاستظهار بالدلائل المصاحبة للأدوية. يجب أن تحمل الوصفات أسعار الأدوية وكذلك طابع الصيدلي.\n\nأ قائمات المصاريف لدى المستشفيات أو المصحات أو العاونين الطبين.\n\nأرخص بصريح العبارة على جمع ومعالجة البيانات المتعلقة بالصحة والتي تعتبر ضرورية للتصرف في عفد التأمين, تتم معالجة\nالبيانات من قبل المصالح المختصة بتأمينات ستار وفقا لقواعد السرية.\nمكن لهذه البيانات موضوع إحالة الى معيدي التأمين أو المناولين المرخص لهم لتلقي و معالجة هذا النوع من البيانات. كما\nيمكن استخدامها أو نقلها لتلبية إلتزامات قانولية وترتيبية. تحدث هذه الإحالات في ظروف تضمن حماية البيانات الشخصية.\nيتم إرسال نتائج التحاليل البيولوجية و الأعمال الطبية بطلب من تأمينات ستار مع ضمان كامل المريّة.\nكل من يتعمد إعلاما كاذبا يكون عرضة للتثبعات العدل \u200eà\u2
# ...

# %%
import cv2
import pytesseract
from PIL import Image
import re

# Définir le chemin correct vers Tesseract si nécessaire
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# Chemin vers l'image
image = "C:/Users/emnad/Downloads/dataclass/bulletin_de_soin/bs1.jpg"

# Extraire le texte en français et en arabe
raw_text = pytesseract.image_to_string(image, lang="fra+ara")

# Nettoyer le texte en supprimant les caractères invisibles
clean_text = re.sub(r'[\u200e\u200f]', '', raw_text)

# Afficher le texte propre
print("Texte extrait :\n", clean_text)
# Out:
# Texte extrait :
#  L | Contractant
# et cachet
#
# توصيات هامة
#
# يجب على المؤمن له أن يوجه هذه البطاقة إلى تأمينات ستار في غضون ثلاثون يوماعلى أقصى تقدير من تاريخ الوصفة الطبية
#
# أو العلاج الطبي تفاديا لكل حرمان من التعويض. ë ;
#
# يجب مصاحبة هذه البطاقة بالوثائق التالية :
#
# الاستظهار بالدلائل المصاحبة للأدوية. يجب أن تحمل الوصفات أسعار الأدوية وكذلك طابع الصيدلي.
#
# أ قائمات المصاريف لدى المستشفيات أو المصحات أو العاونين الطبين.
#
# أرخص بصريح العبارة على جمع ومعالجة البيانات المتعلقة بالصحة والتي تعتبر ضرورية للتصرف في عفد التأمين, تتم معالجة
# البيانات من قبل المصالح المختصة بتأمينات ستار وفقا لقواعد السرية.
# مكن لهذه البيانات موضوع إحالة الى معيدي التأمين أو المناولين المرخص لهم لتلقي و معالجة هذا النوع من البيانات. كما
# يمكن استخدامها أو نقلها لتلبية إلتزامات قانولية وترتيبية. تحدث هذه الإحالات في ظروف تضمن حماية البيانات الشخصية.
# يتم إرسال نتائج التحاليل البيولوجية و الأعمال الطبية بطلب من تأمينات ستار مع ضمان كامل المريّة.
# ...

# %%
import pytesseract

print(pytesseract.get_tesseract_version())  # Check if Tesseract is detected
print(pytesseract.get_languages(config=''))  # Check available languages
# Out:
# 5.5.0.20241111
# ['ara', 'eng', 'fra', 'osd']

# %%
pip list
# Out:
# Package                           Version
# --------------------------------- ------------------
# absl-py                           2.1.0
# aiobotocore                       2.12.3
# aiohappyeyeballs                  2.4.0
# aiohttp                           3.10.5
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.16
# albucore                          0.0.13
# albumentations                    1.4.10
# altair                            5.0.1
# anaconda-anon-usage               0.4.4
# anaconda-catalogs                 0.2.0
# anaconda-client                   1.12.3
# anaconda-cloud-auth               0.5.1
# anaconda-navigator                2.6.3
# anaconda-project                  0.11.1
# annotated-types                   0.6.0
# anyio                             4.2.0
# appdirs                           1.4.4
# archspec                          0.2.3
# argon2-cffi                       21.3.0
# ...

# %%
import easyocr
reader = easyocr.Reader(['fr'], gpu=False)
image=r"C:\Users\emnad\Downloads\02659137-99d3-4c8f-adbe-6d3d2c52272b.jpeg"
result = reader.readtext(image, detail=0)
print("\n".join(result))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# >
# 8
# 0
# 9
# 56
# 0
# 89
# "
# 1
# 4
# 2
# 8
# 8
# K knh
# 2
# 82
# {
# 8
# 2
# 0
# 88
# 8
# 3
# 8
# 4
# 6
# 848
# 3
# 1D
# 8
# 8
# 8984
# 6
# 3
# 2
# 1
# H
# 8
# Ule
# 8 7
# 8
# 1
# 82
# {
# 2
# 5
# 8
# 1
# 1
# Fi
# 8
# 4
# {
# 8
# 0
# 0
# [7
# 1
# g
# 0
# n
# @
# 42
# 12
# g
# 4
# 8
# 3
# 8883
# 5
# 8888
# F
# enoiee
# 1
# 1
# 7
# 4 =
# 5
# 8
# |s'
# 1
#  lg s:  ;k
# ;
# 8
# 1
#
#
# ta
#
# 8lovz
# Fonwv|
# 5
# "0275
# 8
# Ci
# ;l
# 2
# PPT
# M3ouT
# !
# 1
# 9
# 9
# 1
# ,
#
#
# "a:
# 1
# 9
# oonuu8
# 2240

# %%
import cv2
import pytesseract
import numpy as np
import re
import matplotlib.pyplot as plt

# Définir le chemin correct vers Tesseract si nécessaire
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# Chemin vers l'image
image_path = r"C:\Users\emnad\Downloads\bs2.jpg"
# Charger l'image
image = cv2.imread(image_path)

# Vérifier si l'image a été correctement chargée
if image is None:
    print("❌ Erreur lors du chargement de l'image.")
else:
    # Convertir l'image en niveaux de gris
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Binarisation (utilisation de la méthode d'Otsu)
    _, binary_image = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Affichage avec Matplotlib
    plt.imshow(binary_image, cmap='gray')
    plt.axis('off')  # Ne pas afficher les axes
    plt.title("Image binaire")
    plt.show()

    # Appliquer l'OCR sur l'image binaire
    raw_text = pytesseract.image_to_string(binary_image, lang="fra+ara")

    # Nettoyer le texte en supprimant les caractères invisibles
    clean_text = re.sub(r'[\u200e\u200f]', '', raw_text)

    # Afficher le texte propre
    print("Texte extrait :\n", clean_text)

    # Pour l'analyse de la mise en page, récupérer les zones de texte
    boxes = pytesseract.image_to_boxes(binary_image, lang="fra+ara")

    # Afficher les coordonnées des boîtes de texte
    print("Zones de texte détectées :\n", boxes)

    # Optionnel : Dessiner les boîtes sur l'image pour vérifier visuellement
    image_with_boxes = image.copy()
    for box in boxes.splitlines():
        b = box.split()
        x, y, w, h = int(b[1]), int(b[2]), int(b[3]), int(b[4])
        cv2.rectangle(image_with_boxes, (x, h), (w, y), (0, 0, 255), 2)

    # Afficher l'image avec les boîtes de texte
    plt.imshow(cv2.cvtColor(image_with_boxes, cv2.COLOR_BGR2RGB))  # Convertir en RGB pour Matplotlib
    plt.axis('off')  # Ne pas afficher les axes
    plt.title("Image avec boîtes de texte")
    plt.show()
# Out:
# ❌ Erreur lors du chargement de l'image.

# %%
import cv2
import pytesseract
import numpy as np
import matplotlib.pyplot as plt

# Définir le chemin vers Tesseract
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# Charger l'image
image_path = r"C:\Users\emnad\Downloads\bs2.jpg"
image = cv2.imread(image_path)

if image is None:
    print("❌ Impossible de charger l'image.")
else:
    # Convertir en niveaux de gris
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Améliorer le contraste (CLAHE)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    gray = clahe.apply(gray)

    # Binarisation
    _, binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Détection du texte avec position
    data = pytesseract.image_to_data(binary, lang="fra+ara", output_type=pytesseract.Output.DICT)

    # Extraire les positions et textes valides
    text_lines = []
    for i in range(len(data["text"])):
        text = data["text"][i].strip()
        if text:
            x, y, w, h = data["left"][i], data["top"][i], data["width"][i], data["height"][i]
            text_lines.append((y, x, w, h, text))  # Stocker Y pour trier

    # Trier les lignes par position verticale
    text_lines.sort()

    # Séparer les phrases Français / Arabe
    french_texts = []
    arabic_texts = []

    for _, x, _, _, text in text_lines:
        if x < image.shape[1] // 2:  # Texte à gauche (Français)
            french_texts.append(text)
        else:  # Texte à droite (Arabe)
            arabic_texts.append(text)

    # Associer les paires
    paired_texts = list(zip(french_texts, arabic_texts))

    # Afficher les paires bien alignées
    print("\n📜 Paires Français - Arabe :\n")
    for fr, ar in paired_texts:
        print(f"🇫🇷 {fr}  ---  🇦🇪 {ar}")

    # Afficher l'image avec détection des zones
    image_with_boxes = image.copy()
    for y, x, w, h, text in text_lines:
        cv2.rectangle(image_with_boxes, (x, y), (x + w, y + h), (0, 255, 0), 2)

    plt.figure(figsize=(10, 10))
    plt.imshow(cv2.cvtColor(image_with_boxes, cv2.COLOR_BGR2RGB))
    plt.title("Zones détectées")
    plt.axis('off')
    plt.show()
# Out:
# ❌ Impossible de charger l'image.

# %%
pip install tensorflow keras numpy matplotlib opencv-python pillow
# Out:
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.2
#     Uninstalling protobuf-3.20.2:
#       Successfully uninstalled protobuf-3.20.2
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# paddlepaddle 2.6.2 requires protobuf<=3.20.2,>=3.1.0; platform_system == "Windows", but you have protobuf 5.29.3 which is incompatible.

# %% [markdown]
# BO1:

# %% [markdown]
# 1. Méthode basée sur l'apprentissage automatique (classification d'images)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# 🔹 Image parameters
IMG_SIZE = 224  # Image size for MobileNetV2
BATCH_SIZE = 16  # Batch size
EPOCHS = 30  # Increased training epochs
DATASET_PATH = "C:/Users/emnad/Downloads/dataclass"  # Path to dataset

# 🔹 Data Augmentation (for better generalization)
train_datagen = ImageDataGenerator(
    rescale=1./255,  
    validation_split=0.2,  
    rotation_range=30,  
    width_shift_range=0.3, 
    height_shift_range=0.3,
    shear_range=0.3, 
    zoom_range=0.3,
    horizontal_flip=True,
    fill_mode="nearest"
)

# 🔹 Load images from directory
train_generator = train_datagen.flow_from_directory(
    DATASET_PATH,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    DATASET_PATH,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='validation'
)

# 🔹 Load pre-trained MobileNetV2 model
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))

# 🔹 Unfreeze last few layers for better feature learning
base_model.trainable = True
for layer in base_model.layers[:100]:  # Keep first 100 layers frozen
    layer.trainable = False

# 🔹 Add classification layers
x = base_model.output
x = GlobalAveragePooling2D()(x)  
x = Dense(128, activation='relu')(x)  
x = Dense(64, activation='relu')(x)  
predictions = Dense(1, activation='sigmoid')(x)  

# 🔹 Create final model
model = Model(inputs=base_model.input, outputs=predictions)

# 🔹 Compile model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# 🔹 Add Early Stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 🔹 Train the model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping]
)

# 🔹 Save the model
model.save("modele_classification_bs_vs_ordonnance.h5")

# 🔹 Evaluate Model
train_loss, train_acc = model.evaluate(train_generator)
val_loss, val_acc = model.evaluate(val_generator)
print(f"Train Accuracy: {train_acc:.2%}, Validation Accuracy: {val_acc:.2%}")

# 🔹 Plot Accuracy & Loss Curves
plt.figure(figsize=(12, 4))

# Accuracy curve
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label="Training Accuracy")
plt.plot(history.history['val_accuracy'], label="Validation Accuracy")
plt.title("Model Accuracy")
plt.legend()

# Loss curve
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label="Training Loss")
plt.plot(history.history['val_loss'], label="Validation Loss")
plt.title("Model Loss")
plt.legend()

plt.show()
# Out:
# Found 17 images belonging to 2 classes.
# Found 4 images belonging to 2 classes.
# C:\Users\emnad\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.5404 - loss: 0.8296 - val_accuracy: 0.5000 - val_loss: 0.6785
# Epoch 2/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 477ms/step - accuracy: 0.6005 - loss: 0.6424 - val_accuracy: 0.5000 - val_loss: 0.8260
# Epoch 3/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8431 - loss: 0.5733 - val_accuracy: 0.5000 - val_loss: 0.6697
# Epoch 4/30
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 282ms/step - accuracy: 0.8799 - loss: 0.5166 - val_accuracy: 0.5000 - val_loss: 0.6169
# ...

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# Charger le modèle entraîné
model = load_model("modele_classification_bs_vs_ordonnance.h5")

# Fonction pour prédire une image
def predict_image(img_path):
    img = image.load_img(img_path, target_size=(IMG_SIZE, IMG_SIZE))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0  # Normalisation

    prediction = model.predict(img_array)[0][0]
    
    if prediction > 0.5:
        print("✅ C'est une ORDONNANCE")
    else:
        print("✅ C'est un BULLETIN DE SOIN")

# Test avec une image
test_image_path = r"C:\Users\emnad\Downloads\doxaria\8418f58b-43d9-4d05-961d-f1968c23ef42 (1).png"
predict_image(test_image_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# ✅ C'est une ORDONNANCE

# %% [markdown]
# 2. Méthode basée sur la détection de mots-clés

# %%
# !pip install pytesseract opencv-python

# %%
import pytesseract
import cv2
import re
import os
import cv2
# Définir le chemin correct vers Tesseract si nécessaire

# Liste des mots-clés pour chaque type de document
bulletin_soin_keywords = [ "CIN", "Matricule","adherent","منخرط", "Adresse", "Consultation","Bulletin","Bulletin de soins","Assurance","Assurances","STAR","تامينات","ستار","Honoraires"]

# Fonction pour extraire le texte et détecter le type de document
def detect_document_type(image_path):
  


# Vérifier si l'image existe
    if not os.path.exists(image_path):
        print(f"❌ L'image n'existe pas à l'emplacement {image_path}")
    else:
    # Lire l'image
        image = cv2.imread(image_path)
    
    # Vérifier si l'image a été correctement chargée
    if image is None:
        print("❌ Erreur lors du chargement de l'image.")
    else:
        print("✅ Image chargée avec succès.")

    # Appliquer OCR pour extraire le texte
    text = pytesseract.image_to_string(image, lang="fra+ara+eng")

    # Nettoyer le texte pour éviter les caractères invisibles
    clean_text = re.sub(r'[\u200e\u200f]', '', text)

    print("Texte extrait :\n", clean_text)

    # Vérifier la présence des mots-clés
    bulletins_soin_count = sum(1 for keyword in bulletin_soin_keywords if keyword.lower() in clean_text.lower())
    print(bulletins_soin_count)
    if bulletins_soin_count > 0:
        return "Bulletin de soin"
    else:
        return "Ordonnance"

# %%
# Test sur une image
image_path = r"C:\Users\emnad\Downloads\ordonnance1\6fb4b493-ed73-41b5-be0c-3bbca201cb9b (1).png"
document_type = detect_document_type(image_path)
print(f"Type de document détecté : {document_type}")
# Out:
# ✅ Image chargée avec succès.
# Texte extrait :
#  E جه اللي Sonia Abdelhedi ان
#
# Hammami alas}
# Médecine Générale طب عام
# iplômée de la faculté de médecine Geb كلية gus ذم حة
# de Sfax ا 1
#
# ode conventionnel : 1 / 16717/33
#
# Identiiant unique: [ [ [ [11111
# — lQ&VQ/& Ç Ç ;
# TQÇW a 3). K eh
#
# ee
#
# areas : i.
#
# Nom du patient : \¥
#
# الهاتف : 746 545 97
# البريد الإلكتروني : sonia.abdelhedi66@gmail.com
#
#
# 1
# Type de document détecté : Bulletin de soin

# %%
from PIL import Image
import pytesseract
import os
import pandas as pd
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Télécharger les stop words
nltk.download('stopwords')
french_stop_words = stopwords.words('french')

def extract_text_from_image(image_path):
    """Extract text from an image using Tesseract OCR."""
    try:
        img = Image.open(image_path)
        text = pytesseract.image_to_string(img, lang='fra+ara')  # Use 'fra' for French text
        return text
    except Exception as e:
        print(f"Error processing {image_path}: {e}")
        return ""

def extract_text_from_folder(folder_path):
    texts = []
    for filename in os.listdir(folder_path):
        if filename.endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(folder_path, filename)
            text = extract_text_from_image(image_path)
            texts.append(text)
    return texts

# Extract text from both folders
bulletin_texts = extract_text_from_folder("C:/Users/emnad/Downloads/ordonnance/")
other_texts = extract_text_from_folder("C:/Users/emnad/Downloads/bulletin/")

# Create a DataFrame
data = {
    "text": bulletin_texts + other_texts,
    "label": [1] * len(bulletin_texts) + [0] * len(other_texts)  # 1 = bulletin de soin, 0 = other
}
df = pd.DataFrame(data)

# Shuffle the dataset
df = df.sample(frac=1).reset_index(drop=True)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df["text"], df["label"], test_size=0.2, random_state=42)

# Convert text to TF-IDF features
vectorizer = TfidfVectorizer(max_features=1000, stop_words=french_stop_words)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# Train a Logistic Regression model with hyperparameter tuning
model = LogisticRegression(class_weight='balanced')  # Utiliser class_weight pour gérer le déséquilibre
param_grid = {'C': [0.01, 0.1, 1, 10, 100]}
grid_search = GridSearchCV(model, param_grid, cv=5)
grid_search.fit(X_train_tfidf, y_train)

# Evaluate the model
y_pred = grid_search.predict(X_test_tfidf)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))

def classify_document(image_path, confidence_threshold=0.55):
    """
    Classify a new document as 'bulletin de soin', 'ordonnance', or 'unrecognized type'.
    Args:
        image_path (str): Path to the image file.
        confidence_threshold (float): Minimum probability threshold to consider the prediction as reliable.
    Returns:
        str: Classification result.
    """
    text = extract_text_from_image(image_path)
    text_tfidf = vectorizer.transform([text])
   
    # Get prediction probabilities
    probabilities = grid_search.predict_proba(text_tfidf)[0]
    max_probability = max(probabilities)
   
    # Check if the maximum probability is above the threshold
    if max_probability < confidence_threshold:
        return "unrecognized type"
   
    # Otherwise, return the predicted class
    prediction = grid_search.predict(text_tfidf)
    return "bulletin de soin" if prediction[0] == 1 else "ordonnance"

# Test on a new document
new_document_path ="C:/Users/emnad/Downloads/8e23563e-2bb7-48b5-abbf-dca55ea30f81.jpg"  # Remplacez par le chemin de votre image
result = classify_document(new_document_path)
print(f"The document is classified as: {result}")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\emnad\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Accuracy: 1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00        26
#
#     accuracy                           1.00        31
#    macro avg       1.00      1.00      1.00        31
# weighted avg       1.00      1.00      1.00        31
#
# The document is classified as: ordonnance

# %%
new_document_path ="C:/Users/emnad/Downloads/4a2b5470-fcb1-4bef-9af6-2a7aa8ca5601.jpg"  # Remplacez par le chemin de votre image
result = classify_document(new_document_path)
print(f"The document is classified as: {result}")
# Out:
# The document is classified as: ordonnance
